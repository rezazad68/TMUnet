# %%
from __future__ import division
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import torch
import torch.optim as optim
from torch.utils.data import DataLoader
from loader import *
from model.TransMUNet import TransMUNet
import pandas as pd
import glob
import nibabel as nib
import numpy as np
import copy
import yaml

# %%
## Loader
## Hyper parameters
config         = yaml.load(open('./config_skin.yml'), Loader=yaml.FullLoader)
number_classes = int(config['number_classes'])
input_channels = 3
best_val_loss  = np.inf
device = 'cuda' if torch.cuda.is_available() else 'cpu'

data_path = config['path_to_data']  

train_dataset = isic_loader(path_Data = data_path, train = True)
train_loader  = DataLoader(train_dataset, batch_size = int(config['batch_size_tr']), shuffle= True)
val_dataset   = isic_loader(path_Data = data_path, train = False)
val_loader    = DataLoader(val_dataset, batch_size = int(config['batch_size_va']), shuffle= False)

# %%
Net = TransMUNet(n_classes = number_classes)

Net = Net.to(device)
if int(config['pretrained']):
    Net.load_state_dict(torch.load(config['saved_model'], map_location='cpu')['model_weights'])
    best_val_loss = torch.load(config['saved_model'], map_location='cpu')['val_loss']
optimizer = optim.Adam(Net.parameters(), lr= float(config['lr']))
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor = 0.5, patience = config['patience'])
criteria  = torch.nn.BCELoss()
criteria_boundary  = torch.nn.BCELoss()
criteria_region = torch.nn.MSELoss()

# %%
for ep in range(int(config['epochs'])):
    Net.train()
    epoch_loss = 0
    for itter, batch in enumerate(train_loader):
        img = batch['image'].to(device, dtype=torch.float)
        msk = batch['mask'].to(device)
        weak_ann = batch['weak_ann'].to(device)
        boundary = batch['boundary'].to(device)
        mask_type = torch.float32 if Net.n_classes == 1 else torch.long
        msk = msk.to(device=device, dtype=mask_type)
        weak_ann = weak_ann.to(device=device, dtype=mask_type)
        boundary = boundary.to(device=device, dtype=mask_type)
        msk_pred, B, R = Net(img, with_additional=True)
        loss          = criteria(msk_pred, msk) 
        loss_regions  = criteria_region(weak_ann[:,0], R[:,:-1,0])
        loss_boundary = criteria(msk_pred, msk)  
        tloss    = (0.7*(loss)) + (0.1* loss_regions) + (0.2*loss_boundary)
        optimizer.zero_grad()
        tloss.backward()
        epoch_loss += tloss.item()
        optimizer.step()  
        if itter%int(float(config['progress_p']) * len(train_loader))==0:
            print(f' Epoch>> {ep+1} and itteration {itter+1} Loss>> {((epoch_loss/(itter+1)))}')
    ## Validation phase
    with torch.no_grad():
        print('val_mode')
        val_loss = 0
        Net.eval()
        for itter, batch in enumerate(val_loader):
            img = batch['image'].to(device, dtype=torch.float)
            msk = batch['mask'].to(device)
            mask_type = torch.float32 if Net.n_classes == 1 else torch.long
            msk = msk.to(device=device, dtype=mask_type)
            msk_pred = Net(img)
            loss = criteria(msk_pred, msk) 
            val_loss += loss.item()
        print(f' validation on epoch>> {ep+1} dice loss>> {(abs(val_loss/(itter+1)))}')     
        mean_val_loss = (val_loss/(itter+1))
        # Check the performance and save the model
        if (mean_val_loss) < best_val_loss:
            print('New best loss, saving...')
            best_val_loss = copy.deepcopy(mean_val_loss)
            state = copy.deepcopy({'model_weights': Net.state_dict(), 'val_loss': best_val_loss})
            torch.save(state, config['saved_model'])

    scheduler.step(mean_val_loss)
    
print('Trainng phase finished')
# Out:
#  Epoch>> 1 and itteration 1 Loss>> 0.4878859519958496
#  Epoch>> 40 and itteration 1 Loss>> 0.06737198680639267
#  Epoch>> 40 and itteration 46 Loss>> 0.05826217575889567
#  Epoch>> 40 and itteration 91 Loss>> 0.06189956708432554
#  Epoch>> 40 and itteration 136 Loss>> 0.06234927545301616
#  Epoch>> 40 and itteration 181 Loss>> 0.06159386576992043
#  Epoch>> 40 and itteration 226 Loss>> 0.06031691571450339
#  Epoch>> 40 and itteration 271 Loss>> 0.060595802213598005
#  Epoch>> 40 and itteration 316 Loss>> 0.06051208599340878
#  Epoch>> 40 and itteration 361 Loss>> 0.06145136181646932
#  Epoch>> 40 and itteration 406 Loss>> 0.06185557037188208
#  Epoch>> 40 and itteration 451 Loss>> 0.061458513739533274
# val_mode
#  validation on epoch>> 40 dice loss>> 0.15452070934086692
#  Epoch>> 41 and itteration 1 Loss>> 0.03912198916077614
#  Epoch>> 41 and itteration 46 Loss>> 0.05562007605381634
#  Epoch>> 41 and itteration 91 Loss>> 0.05661109134882361
#  Epoch>> 41 and itteration 136 Loss>> 0.057752931901418114
#  Epoch>> 41 and itteration 181 Loss>> 0.05950716551578506
#  Epoch>> 41 and itteration 226 Loss>> 0.06012223679077836
#  Epoch>> 41 and itteration 271 Loss>> 0.059869088741136216
#  Epoch>> 41 and itteration 316 Loss>> 0.059420389235255465
#  Epoch>> 41 and itteration 361 Loss>> 0.05903769401095581
#  Epoch>> 41 and itteration 406 Loss>> 0.059313742031017545
#  Epoch>> 41 and itteration 451 Loss>> 0.05913250953239903
# val_mode
#  validation on epoch>> 41 dice loss>> 0.14478289365452
#  Epoch>> 42 and itteration 1 Loss>> 0.04954291880130768
#  Epoch>> 42 and itteration 46 Loss>> 0.057358553066201835
#  Epoch>> 42 and itteration 91 Loss>> 0.05634032947185275
#  Epoch>> 42 and itteration 136 Loss>> 0.056479945587103855
#  Epoch>> 42 and itteration 181 Loss>> 0.05754764411001574
#  Epoch>> 42 and itteration 226 Loss>> 0.05610715812154576
#  Epoch>> 42 and itteration 271 Loss>> 0.055131187222595586
#  Epoch>> 42 and itteration 316 Loss>> 0.05504096161479814
#  Epoch>> 42 and itteration 361 Loss>> 0.05585714593694811
#  Epoch>> 42 and itteration 406 Loss>> 0.05582418507469699
#  Epoch>> 42 and itteration 451 Loss>> 0.056325403325044925
# val_mode
#  validation on epoch>> 42 dice loss>> 0.1351057186194167
#  Epoch>> 43 and itteration 1 Loss>> 0.057237982749938965
#  Epoch>> 43 and itteration 46 Loss>> 0.0656402307845976
#  Epoch>> 43 and itteration 91 Loss>> 0.05910175396027146
#  Epoch>> 43 and itteration 136 Loss>> 0.05813514297444593
#  Epoch>> 43 and itteration 181 Loss>> 0.057465322912562615
#  Epoch>> 43 and itteration 226 Loss>> 0.05784972177703032
#  Epoch>> 43 and itteration 271 Loss>> 0.05769379498828821
#  Epoch>> 43 and itteration 316 Loss>> 0.05719733570667007
#  Epoch>> 43 and itteration 361 Loss>> 0.05716557138782624
#  Epoch>> 43 and itteration 406 Loss>> 0.05725260248196683
#  Epoch>> 43 and itteration 451 Loss>> 0.057393912638965046
# val_mode
#  validation on epoch>> 43 dice loss>> 0.14248319152152908
#  Epoch>> 44 and itteration 1 Loss>> 0.04875374585390091
#  Epoch>> 44 and itteration 46 Loss>> 0.06167426907821842
#  Epoch>> 44 and itteration 91 Loss>> 0.06074637145950244
#  Epoch>> 44 and itteration 136 Loss>> 0.05821837202700622
#  Epoch>> 44 and itteration 181 Loss>> 0.05800442931689939
#  Epoch>> 44 and itteration 226 Loss>> 0.05671893154987983
#  Epoch>> 44 and itteration 271 Loss>> 0.055853585853512876
#  Epoch>> 44 and itteration 316 Loss>> 0.05678048001342936
#  Epoch>> 44 and itteration 361 Loss>> 0.05700655480191483
#  Epoch>> 44 and itteration 406 Loss>> 0.05674053115650938
#  Epoch>> 44 and itteration 451 Loss>> 0.056278321024716034
# val_mode
#  validation on epoch>> 44 dice loss>> 0.15530629281645
#  Epoch>> 45 and itteration 1 Loss>> 0.09440137445926666
#  Epoch>> 45 and itteration 46 Loss>> 0.05830118983336117
#  Epoch>> 45 and itteration 91 Loss>> 0.05584482134289139
#  Epoch>> 45 and itteration 136 Loss>> 0.05437445165315533
#  Epoch>> 45 and itteration 181 Loss>> 0.05400324788829569
#  Epoch>> 45 and itteration 226 Loss>> 0.05412796204003085
#  Epoch>> 45 and itteration 271 Loss>> 0.05342981169804436
#  Epoch>> 45 and itteration 316 Loss>> 0.05341213810127936
#  Epoch>> 45 and itteration 361 Loss>> 0.05428867298500855
#  Epoch>> 45 and itteration 406 Loss>> 0.05467352060958963
#  Epoch>> 45 and itteration 451 Loss>> 0.05482614739176439
# val_mode
#  validation on epoch>> 45 dice loss>> 0.1467072245589382
#  Epoch>> 46 and itteration 1 Loss>> 0.05303681641817093
#  Epoch>> 46 and itteration 46 Loss>> 0.054856372713718723
#  Epoch>> 46 and itteration 91 Loss>> 0.05333662286892042
#  Epoch>> 46 and itteration 136 Loss>> 0.05294356738929363
#  Epoch>> 46 and itteration 181 Loss>> 0.053488003501658284
#  Epoch>> 46 and itteration 226 Loss>> 0.053084083140489804
#  Epoch>> 46 and itteration 271 Loss>> 0.05295949561926931
#  Epoch>> 46 and itteration 316 Loss>> 0.05325435338353243
#  Epoch>> 46 and itteration 361 Loss>> 0.05346437517832191
#  Epoch>> 46 and itteration 406 Loss>> 0.05294467103231717
#  Epoch>> 46 and itteration 451 Loss>> 0.05362181119339958
# val_mode
#  validation on epoch>> 46 dice loss>> 0.15701383395789328
#  Epoch>> 47 and itteration 1 Loss>> 0.038202621042728424
#  Epoch>> 47 and itteration 46 Loss>> 0.05354265961796045
#  Epoch>> 47 and itteration 91 Loss>> 0.05236436496232892
#  Epoch>> 47 and itteration 136 Loss>> 0.05271057191523997
#  Epoch>> 47 and itteration 181 Loss>> 0.05182616357068989
#  Epoch>> 47 and itteration 226 Loss>> 0.05239239897974561
#  Epoch>> 47 and itteration 271 Loss>> 0.05223012228953442
#  Epoch>> 47 and itteration 316 Loss>> 0.053495453287481884
#  Epoch>> 47 and itteration 361 Loss>> 0.05405835971917307
#  Epoch>> 47 and itteration 406 Loss>> 0.0537252500561511
